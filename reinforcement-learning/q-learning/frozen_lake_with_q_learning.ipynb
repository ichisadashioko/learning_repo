# %%
import time
import random
import math
import itertools

# %%
import numpy as np

import gym
from gym.envs.registration import register

# %% [markdown]
# # Q learning
#
# Q learning requires creating a table that has `number_of_actions` columns and `number_of_states` rows.
#
# The `number_of_actions` has to be `discreted`. That means environment with action like `set the car speed` is not suitable for `Q learning`.
#
# The `number_of_states` also has to be `discreted`.
#
# One example environment is suitable for `Q learning` is `FrozenLake-v0`.
#
# It has `action_sapce` contains 4 actions (move north, south, east, and west).
#
# The `observation_space` contains 16 states (the position of the agent in 4x4 grid world).

# %%
class QTable:
    def __init__(self, num_states, num_actions, alpha=0.2, gamma=0.8):
        """
        `alpha`: learning rate

        `gamma`: discount factor
        """
        self.num_states = num_states
        self.num_actions = num_actions
        self.alpha = alpha  # learning rate
        self.gamma = gamma  # discount factor
        # Initialize Q table with 0
        self.q_table = np.zeros((num_states, num_actions), dtype=np.float)

    def update_table(self, state, action, reward, new_state):
        # self.q_table[state, action] = self.q_table[state, action] - self.alpha * (reward + self.gamma * np.max(self.q_table[new_state]) - self.q_table[state, action])

        # or
        self.q_table[state, action] = (1 - self.alpha) * self.q_table[state, action] + \
            self.alpha * (reward + self.gamma *
                          np.max(self.q_table[new_state]))

    def get_next_action(self, state):
        return np.argmax(self.q_table[state])

# %% [markdown]
# ### Register an un-slippery version of `FrozenLake`

# %%
register(
    id='FrozenLakeNotSlippery-v0',
    entry_point='gym.envs.toy_text:FrozenLakeEnv',
    kwargs={'map_name': '4x4', 'is_slippery': False},
)

# %%
# env = gym.make('FrozenLakeNotSlippery-v0')
env = gym.make('FrozenLake-v0')
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %%
hole_states = [5, 7, 11, 12]
goal_states = [15]

hole_reward = -10
goal_reward = 10

# %%
#==========Create a q-table==========#
num_states = env.observation_space.n
num_actions = env.action_space.n
q_table = QTable(num_states, num_actions)

num_episodes = 1000
num_timesteps = 128
# set the percent you want to explore
epsilon = 0.8
decrease_step_per_episode = epsilon / num_episodes

training_log = []
success_count = 0
for episode in range(num_episodes):
    print(f'Episode {episode+1}/{num_episodes} ', end='', flush=True)

    episode_log = []
    state = env.reset()
    for timestep in range(num_timesteps):
        print('-', end='', flush=True)
        #==========Taking action: Explore or Exploit==========#

        if random.uniform(0, 1) < epsilon:
            # Explore: select a random action
            action = random.randrange(num_actions)
            isRand = True
        else:
            # Exploit: select the action with max value (future reward)
            action = q_table.get_next_action(state)
            isRand = False

        new_state, reward, done, info = env.step(action)

        if done and (new_state in hole_states):
            # if fall into hole
            mReward = hole_reward
            print('FAILED', end='', flush=True)
        elif done and (new_state in goal_states):
            # reach the goal
            mReward = goal_reward
            success_count += 1
            print('SUCCESS', end='', flush=True)
        else:
            # haven't fallen into hole
            if state == new_state:
                # the agent slams into the wall (not moving to get points)
                mReward = -1
            else:
                # NOTE
                # do not give reward to the agent for repeated tasks
                # the agent will try to exploit them
                mReward = 0

        #==========Updating the q-table==========#
        q_table.update_table(state, action, mReward, new_state)

        episode_log.append({
            'state': state,
            'action': action,
            'isRand': isRand,
            'reward': mReward,
            'new_state': new_state
        })

        state = new_state
        if done:
            break

    epsilon -= decrease_step_per_episode
    training_log.append(episode_log)
    print()
    
print(f'Completed {success_count}/{num_episodes}')
# Out:
# Episode 1/1000 ---------------------------FAILED
# Episode 2/1000 ------FAILED
# Episode 3/1000 ----FAILED
# Episode 4/1000 --------FAILED
# Episode 5/1000 ---FAILED
# Episode 6/1000 -----------------FAILED
# Episode 7/1000 -----FAILED
# Episode 8/1000 --------------------------FAILED
# Episode 9/1000 -------FAILED
# Episode 10/1000 ---------FAILED
# Episode 11/1000 ------FAILED
# Episode 12/1000 -------------FAILED
# Episode 13/1000 --FAILED
# Episode 14/1000 --------------FAILED
# Episode 15/1000 -------------------FAILED
# Episode 16/1000 ------FAILED
# Episode 17/1000 --------------FAILED
# Episode 18/1000 ---FAILED
# Episode 19/1000 -----FAILED
# Episode 20/1000 ---FAILED
# Episode 21/1000 ----------FAILED
# Episode 22/1000 -------FAILED
# Episode 23/1000 ------FAILED
# Episode 24/1000 --------FAILED
# Episode 25/1000 ---FAILED
# Episode 26/1000 -----FAILED
# Episode 27/1000 -----FAILED
# Episode 28/1000 --FAILED
# Episode 29/1000 ------FAILED
# Episode 30/1000 --------FAILED
# Episode 31/1000 ---------FAILED
# Episode 32/1000 -------------------FAILED
# Episode 33/1000 -----------FAILED
# Episode 34/1000 --------------------------FAILED
# Episode 35/1000 -------FAILED
# Episode 36/1000 ---------------------FAILED
# Episode 37/1000 ------------------------FAILED
# Episode 38/1000 ------------FAILED
# Episode 39/1000 ------FAILED
# Episode 40/1000 ---------FAILED
# Episode 41/1000 -----FAILED
# Episode 42/1000 ------------FAILED
# Episode 43/1000 ------------------FAILED
# Episode 44/1000 --FAILED
# Episode 45/1000 ----FAILED
# Episode 46/1000 -----------FAILED
# Episode 47/1000 ----------FAILED
# Episode 48/1000 ----FAILED
# Episode 49/1000 ---FAILED
# Episode 50/1000 --FAILED
# Episode 51/1000 ----------FAILED
# Episode 52/1000 --------FAILED
# Episode 53/1000 -------FAILED
# Episode 54/1000 ---FAILED
# Episode 55/1000 ---FAILED
# Episode 56/1000 --------------------FAILED
# Episode 57/1000 -------SUCCESS
# Episode 58/1000 -----------FAILED
# Episode 59/1000 ----FAILED
# Episode 60/1000 -----FAILED
# Episode 61/1000 ------FAILED
# Episode 62/1000 -----------FAILED
# Episode 63/1000 -----FAILED
# Episode 64/1000 ------------FAILED
# Episode 65/1000 -----FAILED
# Episode 66/1000 -------FAILED
# Episode 67/1000 ------FAILED
# Episode 68/1000 ------FAILED
# Episode 69/1000 ----------FAILED
# Episode 70/1000 --FAILED
# Episode 71/1000 --------FAILED
# Episode 72/1000 ------FAILED
# Episode 73/1000 -------FAILED
# Episode 74/1000 ------FAILED
# Episode 75/1000 ------FAILED
# Episode 76/1000 --FAILED
# Episode 77/1000 --FAILED
# Episode 78/1000 -------FAILED
# Episode 79/1000 -------SUCCESS
# Episode 80/1000 ---FAILED
# Episode 81/1000 ------------------------FAILED
# Episode 82/1000 ----------FAILED
# Episode 83/1000 --------SUCCESS
# Episode 84/1000 --------------------FAILED
# Episode 85/1000 ----FAILED
# Episode 86/1000 --------------FAILED
# Episode 87/1000 -----FAILED
# Episode 88/1000 ----FAILED
# Episode 89/1000 -----FAILED
# Episode 90/1000 ----------FAILED
# Episode 91/1000 ------------FAILED
# Episode 92/1000 ------FAILED
# Episode 93/1000 ---FAILED
# Episode 94/1000 -------------------FAILED
# Episode 95/1000 ---FAILED
# Episode 96/1000 ----------FAILED
# Episode 97/1000 -----FAILED
# Episode 98/1000 --------FAILED
# Episode 99/1000 ------FAILED
# Episode 100/1000 ------FAILED
# Episode 101/1000 ---------------FAILED
# Episode 102/1000 ------FAILED
# Episode 103/1000 --FAILED
# Episode 104/1000 --------SUCCESS
# Episode 105/1000 --------------FAILED
# Episode 106/1000 --------FAILED
# Episode 107/1000 ---------SUCCESS
# Episode 108/1000 ---------FAILED
# Episode 109/1000 --FAILED
# Episode 110/1000 -------FAILED
# Episode 111/1000 ------FAILED
# Episode 112/1000 ----------FAILED
# Episode 113/1000 ----------------------------------SUCCESS
# Episode 114/1000 ------FAILED
# Episode 115/1000 -----------FAILED
# Episode 116/1000 ----FAILED
# Episode 117/1000 -------------FAILED
# Episode 118/1000 --------FAILED
# Episode 119/1000 --------------FAILED
# Episode 120/1000 ---FAILED
# Episode 121/1000 ----------FAILED
# Episode 122/1000 -----------------------------FAILED
# Episode 123/1000 -------------------------FAILED
# Episode 124/1000 -------------------FAILED
# Episode 125/1000 ------------FAILED
# Episode 126/1000 --------FAILED
# Episode 127/1000 -----------FAILED
# Episode 128/1000 -----------------FAILED
# Episode 129/1000 -------------FAILED
# Episode 130/1000 --------FAILED
# Episode 131/1000 ---------FAILED
# Episode 132/1000 ----------FAILED
# Episode 133/1000 --------------------FAILED
# Episode 134/1000 -------------FAILED
# Episode 135/1000 --------FAILED
# Episode 136/1000 -------FAILED
# Episode 137/1000 ---FAILED
# Episode 138/1000 ---------FAILED
# Episode 139/1000 -------------------FAILED
# Episode 140/1000 --FAILED
# Episode 141/1000 ----FAILED
# Episode 142/1000 -----------------FAILED
# Episode 143/1000 -----------------FAILED
# Episode 144/1000 ----FAILED
# Episode 145/1000 ----------FAILED
# Episode 146/1000 ----FAILED
# Episode 147/1000 ------------FAILED
# Episode 148/1000 -----FAILED
# Episode 149/1000 ------------FAILED
# Episode 150/1000 --------FAILED
# Episode 151/1000 ------FAILED
# Episode 152/1000 ---------FAILED
# Episode 153/1000 -----------FAILED
# Episode 154/1000 --------------------------FAILED
# Episode 155/1000 --------FAILED
# Episode 156/1000 ---------------------FAILED
# Episode 157/1000 --------------FAILED
# Episode 158/1000 ---FAILED
# Episode 159/1000 -------FAILED
# Episode 160/1000 ------------------------------FAILED
# Episode 161/1000 -----FAILED
# Episode 162/1000 -----FAILED
# Episode 163/1000 -----------FAILED
# Episode 164/1000 ----FAILED
# Episode 165/1000 ------FAILED
# Episode 166/1000 ------FAILED
# Episode 167/1000 ------------FAILED
# Episode 168/1000 --FAILED
# Episode 169/1000 --------FAILED
# Episode 170/1000 ---FAILED
# Episode 171/1000 -----------FAILED
# Episode 172/1000 ---------------------FAILED
# Episode 173/1000 ---------FAILED
# Episode 174/1000 ------FAILED
# Episode 175/1000 -----------FAILED
# Episode 176/1000 -------------------------------FAILED
# Episode 177/1000 -------FAILED
# Episode 178/1000 --------------------FAILED
# Episode 179/1000 ---------------SUCCESS
# Episode 180/1000 -----FAILED
# Episode 181/1000 -----FAILED
# Episode 182/1000 -------------------FAILED
# Episode 183/1000 --------FAILED
# Episode 184/1000 ----------------FAILED
# Episode 185/1000 -----FAILED
# Episode 186/1000 ----------FAILED
# Episode 187/1000 ----------SUCCESS
# Episode 188/1000 ----FAILED
# Episode 189/1000 ----FAILED
# Episode 190/1000 ----FAILED
# Episode 191/1000 ---------------------FAILED
# Episode 192/1000 --------------------------FAILED
# Episode 193/1000 ----FAILED
# Episode 194/1000 -----FAILED
# Episode 195/1000 --------------FAILED
# Episode 196/1000 -------------------FAILED
# Episode 197/1000 ------FAILED
# Episode 198/1000 -----FAILED
# Episode 199/1000 ------FAILED
# Episode 200/1000 -------FAILED
# Episode 201/1000 --------FAILED
# Episode 202/1000 ----FAILED
# Episode 203/1000 ------FAILED
# Episode 204/1000 ------------FAILED
# Episode 205/1000 -----FAILED
# Episode 206/1000 --FAILED
# Episode 207/1000 ----------------FAILED
# Episode 208/1000 ---------FAILED
# Episode 209/1000 ----------FAILED
# Episode 210/1000 -------------------FAILED
# Episode 211/1000 ---------FAILED
# Episode 212/1000 -----------------------FAILED
# Episode 213/1000 -------------SUCCESS
# Episode 214/1000 ---------FAILED
# Episode 215/1000 --------FAILED
# Episode 216/1000 --------FAILED
# Episode 217/1000 -----FAILED
# Episode 218/1000 -----------FAILED
# Episode 219/1000 ----------FAILED
# Episode 220/1000 ---FAILED
# Episode 221/1000 ------FAILED
# Episode 222/1000 ---------FAILED
# Episode 223/1000 -------FAILED
# Episode 224/1000 ----FAILED
# Episode 225/1000 -----FAILED
# Episode 226/1000 -----------------FAILED
# Episode 227/1000 --------FAILED
# Episode 228/1000 -----FAILED
# Episode 229/1000 ----------FAILED
# Episode 230/1000 -----------FAILED
# Episode 231/1000 --FAILED
# Episode 232/1000 -----FAILED
# Episode 233/1000 --------FAILED
# Episode 234/1000 ------FAILED
# Episode 235/1000 -------FAILED
# Episode 236/1000 ----------FAILED
# Episode 237/1000 ------------FAILED
# Episode 238/1000 ----------FAILED
# Episode 239/1000 ------------------------FAILED
# Episode 240/1000 --FAILED
# Episode 241/1000 ---------------SUCCESS
# Episode 242/1000 -------FAILED
# Episode 243/1000 ----FAILED
# Episode 244/1000 ------------------FAILED
# Episode 245/1000 ---------FAILED
# Episode 246/1000 ------------------------SUCCESS
# Episode 247/1000 -----FAILED
# Episode 248/1000 --FAILED
# Episode 249/1000 -------FAILED
# Episode 250/1000 ---------------FAILED
# Episode 251/1000 ------FAILED
# Episode 252/1000 ---FAILED
# Episode 253/1000 ---FAILED
# Episode 254/1000 -----------FAILED
# Episode 255/1000 --FAILED
# Episode 256/1000 -------------FAILED
# Episode 257/1000 ----------------FAILED
# Episode 258/1000 ------------FAILED
# Episode 259/1000 --------FAILED
# Episode 260/1000 -------FAILED
# Episode 261/1000 -----------------FAILED
# Episode 262/1000 ------------------------FAILED
# Episode 263/1000 -----FAILED
# Episode 264/1000 ----FAILED
# Episode 265/1000 --------FAILED
# Episode 266/1000 ------FAILED
# Episode 267/1000 ---------------FAILED
# Episode 268/1000 ---------------------------------FAILED
# Episode 269/1000 ----FAILED
# Episode 270/1000 --------------FAILED
# Episode 271/1000 ---------FAILED
# Episode 272/1000 -------------FAILED
# Episode 273/1000 -----------------FAILED
# Episode 274/1000 ---------FAILED
# Episode 275/1000 -----FAILED
# Episode 276/1000 -----FAILED
# Episode 277/1000 -------------------FAILED
# Episode 278/1000 --FAILED
# Episode 279/1000 ----------FAILED
# Episode 280/1000 --------FAILED
# Episode 281/1000 -----FAILED
# Episode 282/1000 -------------FAILED
# Episode 283/1000 --FAILED
# Episode 284/1000 ---------FAILED
# Episode 285/1000 ---FAILED
# Episode 286/1000 --FAILED
# Episode 287/1000 -------------FAILED
# Episode 288/1000 -----------FAILED
# Episode 289/1000 --------------FAILED
# Episode 290/1000 -------FAILED
# Episode 291/1000 ------SUCCESS
# Episode 292/1000 --------FAILED
# Episode 293/1000 ---------------------------FAILED
# Episode 294/1000 ------FAILED
# Episode 295/1000 ------------------------------------FAILED
# Episode 296/1000 --------------------------FAILED
# Episode 297/1000 ----------------------------------FAILED
# Episode 298/1000 ------FAILED
# Episode 299/1000 -------FAILED
# Episode 300/1000 ---------FAILED
# Episode 301/1000 -------SUCCESS
# Episode 302/1000 ------------------FAILED
# Episode 303/1000 ----FAILED
# Episode 304/1000 ----------FAILED
# Episode 305/1000 -----------FAILED
# Episode 306/1000 ---------------FAILED
# Episode 307/1000 --FAILED
# Episode 308/1000 ------------SUCCESS
# Episode 309/1000 ---FAILED
# Episode 310/1000 ------------------FAILED
# Episode 311/1000 ---FAILED
# Episode 312/1000 ----FAILED
# Episode 313/1000 --FAILED
# Episode 314/1000 -----FAILED
# Episode 315/1000 -------------FAILED
# Episode 316/1000 ------FAILED
# Episode 317/1000 --FAILED
# Episode 318/1000 ---------FAILED
# Episode 319/1000 ---------------------FAILED
# Episode 320/1000 -------FAILED
# Episode 321/1000 ---FAILED
# Episode 322/1000 -------FAILED
# Episode 323/1000 -----------------FAILED
# Episode 324/1000 ---FAILED
# Episode 325/1000 ---------------------FAILED
# Episode 326/1000 ----FAILED
# Episode 327/1000 ------FAILED
# Episode 328/1000 -----FAILED
# Episode 329/1000 -----------------------FAILED
# Episode 330/1000 -------FAILED
# Episode 331/1000 --FAILED
# Episode 332/1000 ---------------------FAILED
# Episode 333/1000 --------------------FAILED
# Episode 334/1000 ----FAILED
# Episode 335/1000 ---------------FAILED
# Episode 336/1000 -----------FAILED
# Episode 337/1000 ---FAILED
# Episode 338/1000 ---------FAILED
# Episode 339/1000 ----------------------FAILED
# Episode 340/1000 ------------FAILED
# Episode 341/1000 -----------FAILED
# Episode 342/1000 ------------------FAILED
# Episode 343/1000 --------FAILED
# Episode 344/1000 ------FAILED
# Episode 345/1000 ------FAILED
# Episode 346/1000 ------FAILED
# Episode 347/1000 -------FAILED
# Episode 348/1000 -----FAILED
# Episode 349/1000 -----FAILED
# Episode 350/1000 ---FAILED
# Episode 351/1000 --------------------------------------------------------------------------FAILED
# Episode 352/1000 --FAILED
# Episode 353/1000 --------------------FAILED
# Episode 354/1000 -----------------------FAILED
# Episode 355/1000 ---------------------------FAILED
# Episode 356/1000 ---------------FAILED
# Episode 357/1000 -----FAILED
# Episode 358/1000 ---FAILED
# Episode 359/1000 ---------------------FAILED
# Episode 360/1000 ----FAILED
# Episode 361/1000 -------------------------FAILED
# Episode 362/1000 ----------FAILED
# Episode 363/1000 ---FAILED
# Episode 364/1000 --FAILED
# Episode 365/1000 -----------FAILED
# Episode 366/1000 -------------------------SUCCESS
# Episode 367/1000 ------------------FAILED
# Episode 368/1000 ---------FAILED
# Episode 369/1000 ---FAILED
# Episode 370/1000 --------FAILED
# Episode 371/1000 ---------FAILED
# Episode 372/1000 -----------FAILED
# Episode 373/1000 -------FAILED
# Episode 374/1000 -------FAILED
# Episode 375/1000 -------FAILED
# Episode 376/1000 -------------FAILED
# Episode 377/1000 ---FAILED
# Episode 378/1000 --------------FAILED
# Episode 379/1000 --------------------------------------------------------FAILED
# Episode 380/1000 --FAILED
# Episode 381/1000 ------FAILED
# Episode 382/1000 -------------------FAILED
# Episode 383/1000 -------FAILED
# Episode 384/1000 -----------FAILED
# Episode 385/1000 ----------FAILED
# Episode 386/1000 ---FAILED
# Episode 387/1000 ---FAILED
# Episode 388/1000 ------FAILED
# Episode 389/1000 ------------------------FAILED
# Episode 390/1000 --------FAILED
# Episode 391/1000 ------------------FAILED
# Episode 392/1000 ---FAILED
# Episode 393/1000 ------------------------------FAILED
# Episode 394/1000 -----------FAILED
# Episode 395/1000 -------------------------------------FAILED
# Episode 396/1000 -----------FAILED
# Episode 397/1000 ----------------FAILED
# Episode 398/1000 ----------------------------------------------------------------------------------------------------
# Episode 399/1000 -----------------FAILED
# Episode 400/1000 -------FAILED
# Episode 401/1000 -------------FAILED
# Episode 402/1000 ----FAILED
# Episode 403/1000 ---------------FAILED
# Episode 404/1000 ----------------------FAILED
# Episode 405/1000 ---------FAILED
# Episode 406/1000 -------------FAILED
# Episode 407/1000 -------------FAILED
# Episode 408/1000 --------------------------------------FAILED
# Episode 409/1000 ----FAILED
# Episode 410/1000 ---------FAILED
# Episode 411/1000 --------------------------------------FAILED
# Episode 412/1000 ---FAILED
# Episode 413/1000 ----FAILED
# Episode 414/1000 -------------------------------FAILED
# Episode 415/1000 ------FAILED
# Episode 416/1000 -----------FAILED
# Episode 417/1000 --FAILED
# Episode 418/1000 -----FAILED
# Episode 419/1000 -----------FAILED
# Episode 420/1000 ----------------FAILED
# Episode 421/1000 ------FAILED
# Episode 422/1000 ------------------FAILED
# Episode 423/1000 ---FAILED
# Episode 424/1000 ---------FAILED
# Episode 425/1000 ------FAILED
# Episode 426/1000 --FAILED
# Episode 427/1000 --------------FAILED
# Episode 428/1000 -----------------------FAILED
# Episode 429/1000 ----------FAILED
# Episode 430/1000 --------FAILED
# Episode 431/1000 --------------------FAILED
# Episode 432/1000 -------FAILED
# Episode 433/1000 ---------FAILED
# Episode 434/1000 --------------FAILED
# Episode 435/1000 --FAILED
# Episode 436/1000 --------------FAILED
# Episode 437/1000 --FAILED
# Episode 438/1000 --------------------FAILED
# Episode 439/1000 ------------FAILED
# Episode 440/1000 --------------FAILED
# Episode 441/1000 -----FAILED
# Episode 442/1000 -------FAILED
# Episode 443/1000 ------------FAILED
# Episode 444/1000 ------------------------------------------SUCCESS
# Episode 445/1000 ------------FAILED
# Episode 446/1000 --------------SUCCESS
# Episode 447/1000 --------------------------FAILED
# Episode 448/1000 -----FAILED
# Episode 449/1000 --------------------------FAILED
# Episode 450/1000 ------FAILED
# Episode 451/1000 ---------------------------FAILED
# Episode 452/1000 --------------FAILED
# Episode 453/1000 -----FAILED
# Episode 454/1000 -------FAILED
# Episode 455/1000 --FAILED
# Episode 456/1000 -----------FAILED
# Episode 457/1000 -----------FAILED
# Episode 458/1000 ---------FAILED
# Episode 459/1000 -----------------FAILED
# Episode 460/1000 ----FAILED
# Episode 461/1000 ------------FAILED
# Episode 462/1000 ------------------SUCCESS
# Episode 463/1000 --FAILED
# Episode 464/1000 ------FAILED
# Episode 465/1000 ----------FAILED
# Episode 466/1000 -------FAILED
# Episode 467/1000 ------------FAILED
# Episode 468/1000 ----------FAILED
# Episode 469/1000 ----FAILED
# Episode 470/1000 ------------------FAILED
# Episode 471/1000 -----------FAILED
# Episode 472/1000 ---------FAILED
# Episode 473/1000 ------------------FAILED
# Episode 474/1000 ------------------------------FAILED
# Episode 475/1000 ----FAILED
# Episode 476/1000 ---FAILED
# Episode 477/1000 -----------FAILED
# Episode 478/1000 --FAILED
# Episode 479/1000 -------FAILED
# Episode 480/1000 ------FAILED
# Episode 481/1000 -----FAILED
# Episode 482/1000 ----------FAILED
# Episode 483/1000 --FAILED
# Episode 484/1000 --FAILED
# Episode 485/1000 -------------------FAILED
# Episode 486/1000 ---FAILED
# Episode 487/1000 --------------FAILED
# Episode 488/1000 -------------FAILED
# Episode 489/1000 -----FAILED
# Episode 490/1000 --FAILED
# Episode 491/1000 ------FAILED
# Episode 492/1000 -----------FAILED
# Episode 493/1000 -------------FAILED
# Episode 494/1000 -----------------FAILED
# Episode 495/1000 ---FAILED
# Episode 496/1000 -------FAILED
# Episode 497/1000 --------------SUCCESS
# Episode 498/1000 -----------FAILED
# Episode 499/1000 -------------------------SUCCESS
# Episode 500/1000 ------FAILED
# Episode 501/1000 ---FAILED
# Episode 502/1000 ---FAILED
# Episode 503/1000 --FAILED
# Episode 504/1000 ---FAILED
# Episode 505/1000 ---------------FAILED
# Episode 506/1000 ---------------FAILED
# Episode 507/1000 ---FAILED
# Episode 508/1000 -------------------FAILED
# Episode 509/1000 ------FAILED
# Episode 510/1000 -------------------------------FAILED
# Episode 511/1000 ----------------FAILED
# Episode 512/1000 ----FAILED
# Episode 513/1000 --------------------FAILED
# Episode 514/1000 --------------FAILED
# Episode 515/1000 -------------------------------------------------------------SUCCESS
# Episode 516/1000 -------------------------------SUCCESS
# Episode 517/1000 --------------------FAILED
# Episode 518/1000 ---FAILED
# Episode 519/1000 -----------------------FAILED
# Episode 520/1000 ---FAILED
# Episode 521/1000 --FAILED
# Episode 522/1000 ----------FAILED
# Episode 523/1000 ----------------FAILED
# Episode 524/1000 ---------------FAILED
# Episode 525/1000 --FAILED
# Episode 526/1000 -------------------FAILED
# Episode 527/1000 -----------FAILED
# Episode 528/1000 ---------------------------FAILED
# Episode 529/1000 -----------------------FAILED
# Episode 530/1000 ---------------FAILED
# Episode 531/1000 ----------------------------------------------------SUCCESS
# Episode 532/1000 --FAILED
# Episode 533/1000 --------------------FAILED
# Episode 534/1000 ------------SUCCESS
# Episode 535/1000 ----------------------FAILED
# Episode 536/1000 -------FAILED
# Episode 537/1000 ------FAILED
# Episode 538/1000 ---------------------------SUCCESS
# Episode 539/1000 --------FAILED
# Episode 540/1000 --------------------FAILED
# Episode 541/1000 ------------FAILED
# Episode 542/1000 ---FAILED
# Episode 543/1000 ---------FAILED
# Episode 544/1000 -----FAILED
# Episode 545/1000 -------------------FAILED
# Episode 546/1000 ---------------FAILED
# Episode 547/1000 --------------FAILED
# Episode 548/1000 ------FAILED
# Episode 549/1000 --------FAILED
# Episode 550/1000 -----------------SUCCESS
# Episode 551/1000 -------------------------FAILED
# Episode 552/1000 ----------------SUCCESS
# Episode 553/1000 -----FAILED
# Episode 554/1000 ---------------SUCCESS
# Episode 555/1000 --------------FAILED
# Episode 556/1000 -------------------FAILED
# Episode 557/1000 ---------FAILED
# Episode 558/1000 ------------FAILED
# Episode 559/1000 ----------------FAILED
# Episode 560/1000 -------FAILED
# Episode 561/1000 ---------------------------------------FAILED
# Episode 562/1000 -----FAILED
# Episode 563/1000 -------------------------------SUCCESS
# Episode 564/1000 -----------------FAILED
# Episode 565/1000 ------------FAILED
# Episode 566/1000 ----FAILED
# Episode 567/1000 ----------------SUCCESS
# Episode 568/1000 -----------SUCCESS
# Episode 569/1000 ----------------------------SUCCESS
# Episode 570/1000 ---------FAILED
# Episode 571/1000 -----------FAILED
# Episode 572/1000 ---------------------------------FAILED
# Episode 573/1000 --------FAILED
# Episode 574/1000 ------------------FAILED
# Episode 575/1000 ----------FAILED
# Episode 576/1000 ----FAILED
# Episode 577/1000 -----------FAILED
# Episode 578/1000 ---FAILED
# Episode 579/1000 --FAILED
# Episode 580/1000 ------FAILED
# Episode 581/1000 ----FAILED
# Episode 582/1000 --FAILED
# Episode 583/1000 ------------FAILED
# Episode 584/1000 ------------------------------------------------------------------FAILED
# Episode 585/1000 -------------------FAILED
# Episode 586/1000 ------------------------------------SUCCESS
# Episode 587/1000 --------------------------------FAILED
# Episode 588/1000 ---------------FAILED
# Episode 589/1000 ---------------------FAILED
# Episode 590/1000 ----------------------------------------------------------FAILED
# Episode 591/1000 ----FAILED
# Episode 592/1000 ---FAILED
# Episode 593/1000 ----FAILED
# Episode 594/1000 ------------SUCCESS
# Episode 595/1000 ----FAILED
# Episode 596/1000 --------------------------FAILED
# Episode 597/1000 ----FAILED
# Episode 598/1000 ---------FAILED
# Episode 599/1000 ---------------FAILED
# Episode 600/1000 ----FAILED
# Episode 601/1000 -----FAILED
# Episode 602/1000 --------FAILED
# Episode 603/1000 ---------FAILED
# Episode 604/1000 ---------------------SUCCESS
# Episode 605/1000 ------FAILED
# Episode 606/1000 --------------------------------------FAILED
# Episode 607/1000 ----FAILED
# Episode 608/1000 ---FAILED
# Episode 609/1000 -----------FAILED
# Episode 610/1000 ---FAILED
# Episode 611/1000 -----------FAILED
# Episode 612/1000 ------------------------FAILED
# Episode 613/1000 ----------FAILED
# Episode 614/1000 ------------------------------------FAILED
# Episode 615/1000 -----------FAILED
# Episode 616/1000 --FAILED
# Episode 617/1000 -----------FAILED
# Episode 618/1000 ----FAILED
# Episode 619/1000 ---------------------------------SUCCESS
# Episode 620/1000 ---FAILED
# Episode 621/1000 -------------FAILED
# Episode 622/1000 -------------FAILED
# Episode 623/1000 -----------FAILED
# Episode 624/1000 -----------------------FAILED
# Episode 625/1000 ---------------------------------------FAILED
# Episode 626/1000 ------------------------FAILED
# Episode 627/1000 -------FAILED
# Episode 628/1000 ----------------------------FAILED
# Episode 629/1000 -------------FAILED
# Episode 630/1000 ---------------SUCCESS
# Episode 631/1000 -------------FAILED
# Episode 632/1000 -----FAILED
# Episode 633/1000 --------FAILED
# Episode 634/1000 --------------------FAILED
# Episode 635/1000 -------------------FAILED
# Episode 636/1000 ----------------------------FAILED
# Episode 637/1000 --------------------------------------------------------FAILED
# Episode 638/1000 ----FAILED
# Episode 639/1000 ---FAILED
# Episode 640/1000 -----------FAILED
# Episode 641/1000 --------------FAILED
# Episode 642/1000 ---------FAILED
# Episode 643/1000 --------FAILED
# Episode 644/1000 ------FAILED
# Episode 645/1000 -----FAILED
# Episode 646/1000 ------FAILED
# Episode 647/1000 ---------------------FAILED
# Episode 648/1000 -----------------------FAILED
# Episode 649/1000 ----------------------FAILED
# Episode 650/1000 -------------------------SUCCESS
# Episode 651/1000 --------------FAILED
# Episode 652/1000 -----------FAILED
# Episode 653/1000 ------------------------FAILED
# Episode 654/1000 ----------FAILED
# Episode 655/1000 -----------------SUCCESS
# Episode 656/1000 ----------------------------FAILED
# Episode 657/1000 ---------FAILED
# Episode 658/1000 -----------------------------------SUCCESS
# Episode 659/1000 ---FAILED
# Episode 660/1000 --------------FAILED
# Episode 661/1000 --------FAILED
# Episode 662/1000 ---------FAILED
# Episode 663/1000 ---------FAILED
# Episode 664/1000 ---------------------------FAILED
# Episode 665/1000 -----------------------FAILED
# Episode 666/1000 -----------------------------FAILED
# Episode 667/1000 ------------FAILED
# Episode 668/1000 ---------------SUCCESS
# Episode 669/1000 ---------------SUCCESS
# Episode 670/1000 ---------------------------SUCCESS
# Episode 671/1000 ------------------------FAILED
# Episode 672/1000 ------------------FAILED
# Episode 673/1000 -----FAILED
# Episode 674/1000 -------------FAILED
# Episode 675/1000 -----FAILED
# Episode 676/1000 -------------FAILED
# Episode 677/1000 ----FAILED
# Episode 678/1000 --------FAILED
# Episode 679/1000 -----FAILED
# Episode 680/1000 ----------------FAILED
# Episode 681/1000 -----------FAILED
# Episode 682/1000 -----------------------------SUCCESS
# Episode 683/1000 --FAILED
# Episode 684/1000 ----FAILED
# Episode 685/1000 ------------SUCCESS
# Episode 686/1000 -------------FAILED
# Episode 687/1000 ---------------------FAILED
# Episode 688/1000 -----------------FAILED
# Episode 689/1000 ------FAILED
# Episode 690/1000 ----------FAILED
# Episode 691/1000 ---FAILED
# Episode 692/1000 ---------FAILED
# Episode 693/1000 ------------------------------------SUCCESS
# Episode 694/1000 ----FAILED
# Episode 695/1000 ---------------------------------------------FAILED
# Episode 696/1000 --------------FAILED
# Episode 697/1000 ------FAILED
# Episode 698/1000 -------FAILED
# Episode 699/1000 -------FAILED
# Episode 700/1000 ------FAILED
# Episode 701/1000 ------------------------------------------------------------FAILED
# Episode 702/1000 --------------------------------------------------------------------------FAILED
# Episode 703/1000 --------------------FAILED
# Episode 704/1000 ---FAILED
# Episode 705/1000 ----------------------------------FAILED
# Episode 706/1000 --------FAILED
# Episode 707/1000 -----------------FAILED
# Episode 708/1000 -----------FAILED
# Episode 709/1000 --------------------------------------------FAILED
# Episode 710/1000 ---FAILED
# Episode 711/1000 ----------------------FAILED
# Episode 712/1000 ---------------------------FAILED
# Episode 713/1000 --------------FAILED
# Episode 714/1000 -----------------------------SUCCESS
# Episode 715/1000 -----------------------------------------FAILED
# Episode 716/1000 --FAILED
# Episode 717/1000 ------------FAILED
# Episode 718/1000 --FAILED
# Episode 719/1000 --FAILED
# Episode 720/1000 ------------------FAILED
# Episode 721/1000 ------------------------------------------------FAILED
# Episode 722/1000 -------------------------------------FAILED
# Episode 723/1000 -----------------FAILED
# Episode 724/1000 --------------------------------FAILED
# Episode 725/1000 -----------FAILED
# Episode 726/1000 --------FAILED
# Episode 727/1000 --------FAILED
# Episode 728/1000 -----------------------------------------------------FAILED
# Episode 729/1000 --------------FAILED
# Episode 730/1000 --------------------------FAILED
# Episode 731/1000 --------------------FAILED
# Episode 732/1000 -------------------SUCCESS
# Episode 733/1000 ----------FAILED
# Episode 734/1000 -------------FAILED
# Episode 735/1000 --------------------------------------------SUCCESS
# Episode 736/1000 -----FAILED
# Episode 737/1000 ---------FAILED
# Episode 738/1000 ---------------SUCCESS
# Episode 739/1000 -----------FAILED
# Episode 740/1000 ------FAILED
# Episode 741/1000 --FAILED
# Episode 742/1000 --------SUCCESS
# Episode 743/1000 -----FAILED
# Episode 744/1000 ----------FAILED
# Episode 745/1000 ---------------------------FAILED
# Episode 746/1000 ---------FAILED
# Episode 747/1000 ------FAILED
# Episode 748/1000 ----------------FAILED
# Episode 749/1000 -------FAILED
# Episode 750/1000 ------------------------------FAILED
# Episode 751/1000 ------------------FAILED
# Episode 752/1000 -------------------------FAILED
# Episode 753/1000 ----------------------FAILED
# Episode 754/1000 ----------------FAILED
# Episode 755/1000 ---------------------FAILED
# Episode 756/1000 ---FAILED
# Episode 757/1000 ------------------FAILED
# Episode 758/1000 -------------FAILED
# Episode 759/1000 ------------------------------FAILED
# Episode 760/1000 ---------FAILED
# Episode 761/1000 --------------------------------SUCCESS
# Episode 762/1000 ------------SUCCESS
# Episode 763/1000 ---------------------------------FAILED
# Episode 764/1000 ------------FAILED
# Episode 765/1000 -------FAILED
# Episode 766/1000 ------------------SUCCESS
# Episode 767/1000 --FAILED
# Episode 768/1000 -----------------------FAILED
# Episode 769/1000 --FAILED
# Episode 770/1000 --FAILED
# Episode 771/1000 ----FAILED
# Episode 772/1000 --------------------------------------FAILED
# Episode 773/1000 -----------SUCCESS
# Episode 774/1000 -------------------------FAILED
# Episode 775/1000 -----FAILED
# Episode 776/1000 ------------FAILED
# Episode 777/1000 ------------------------------------FAILED
# Episode 778/1000 ------------------SUCCESS
# Episode 779/1000 --------------------------------------------------------------------------------FAILED
# Episode 780/1000 ----------------------------------------------------SUCCESS
# Episode 781/1000 ----------------------------------------------------------------------FAILED
# Episode 782/1000 -----FAILED
# Episode 783/1000 -----FAILED
# Episode 784/1000 ---------FAILED
# Episode 785/1000 ------------SUCCESS
# Episode 786/1000 ---------FAILED
# Episode 787/1000 ---------------------------------------FAILED
# Episode 788/1000 ---------------------------------------------------------------------------------------------FAILED
# Episode 789/1000 ---FAILED
# Episode 790/1000 ---------------------------------------SUCCESS
# Episode 791/1000 -----------------SUCCESS
# Episode 792/1000 -----------------------FAILED
# Episode 793/1000 -------------------------FAILED
# Episode 794/1000 -----------------------------------------FAILED
# Episode 795/1000 -----FAILED
# Episode 796/1000 --------------------FAILED
# Episode 797/1000 ------------------------------------------------------FAILED
# Episode 798/1000 -----------FAILED
# Episode 799/1000 --------------SUCCESS
# Episode 800/1000 -------------------------------FAILED
# Episode 801/1000 ----FAILED
# Episode 802/1000 ------------------------------------------FAILED
# Episode 803/1000 ------FAILED
# Episode 804/1000 ---------------SUCCESS
# Episode 805/1000 -----------------FAILED
# Episode 806/1000 -----------------------------FAILED
# Episode 807/1000 ---------------------------------------FAILED
# Episode 808/1000 --------------SUCCESS
# Episode 809/1000 -----------------FAILED
# Episode 810/1000 ----------------------------------------------------------FAILED
# Episode 811/1000 ---------------FAILED
# Episode 812/1000 --------------------SUCCESS
# Episode 813/1000 -------------------------------------FAILED
# Episode 814/1000 --------------------------------------------------------SUCCESS
# Episode 815/1000 ---------FAILED
# Episode 816/1000 -------------------------SUCCESS
# Episode 817/1000 ------------------------------------------------------------------------------FAILED
# Episode 818/1000 -------FAILED
# Episode 819/1000 ----------------------------------FAILED
# Episode 820/1000 ----------------FAILED
# Episode 821/1000 --------------------------------FAILED
# Episode 822/1000 -------FAILED
# Episode 823/1000 ----FAILED
# Episode 824/1000 ---------FAILED
# Episode 825/1000 ----------------------SUCCESS
# Episode 826/1000 ----FAILED
# Episode 827/1000 --------------------------------FAILED
# Episode 828/1000 ------------------FAILED
# Episode 829/1000 --------FAILED
# Episode 830/1000 --------FAILED
# Episode 831/1000 ---------------------------------------------FAILED
# Episode 832/1000 ---------------------------------SUCCESS
# Episode 833/1000 ----------------------------------------------------------FAILED
# Episode 834/1000 ------------------SUCCESS
# Episode 835/1000 ----------------------------------------------------------------------------------------------------
# Episode 836/1000 -------------------------------------SUCCESS
# Episode 837/1000 -----------------FAILED
# Episode 838/1000 --------------------------FAILED
# Episode 839/1000 ---FAILED
# Episode 840/1000 ----------------------------------------------------FAILED
# Episode 841/1000 ------------------------------------------------FAILED
# Episode 842/1000 ----------------------------------------------------------------------------------------------------
# Episode 843/1000 -----------------------------------FAILED
# Episode 844/1000 --------------------SUCCESS
# Episode 845/1000 ---------------------------------------------------------------------FAILED
# Episode 846/1000 ---------------------------FAILED
# Episode 847/1000 ----------------------SUCCESS
# Episode 848/1000 ---------------FAILED
# Episode 849/1000 --------------------------------------------------------------------------FAILED
# Episode 850/1000 ------FAILED
# Episode 851/1000 -------------------------FAILED
# Episode 852/1000 -----------------------------------SUCCESS
# Episode 853/1000 -------------------------------------------FAILED
# Episode 854/1000 --------------------------------------FAILED
# Episode 855/1000 ---------------------FAILED
# Episode 856/1000 ---------SUCCESS
# Episode 857/1000 ----------FAILED
# Episode 858/1000 ---------------FAILED
# Episode 859/1000 -----------------------------------FAILED
# Episode 860/1000 ---------FAILED
# Episode 861/1000 --------------------------------------------SUCCESS
# Episode 862/1000 -----FAILED
# Episode 863/1000 --------------FAILED
# Episode 864/1000 --------------------------FAILED
# Episode 865/1000 --------------------------------------FAILED
# Episode 866/1000 ---------------------------------------FAILED
# Episode 867/1000 -----------------------------------------FAILED
# Episode 868/1000 ----------------------------------------------------------------------------------------------------
# Episode 869/1000 ----------------------------------------------------------------------------------------------------
# Episode 870/1000 ------------------------------------------------------------FAILED
# Episode 871/1000 ------------------SUCCESS
# Episode 872/1000 --------------------------------------------------SUCCESS
# Episode 873/1000 ----------------------------------------FAILED
# Episode 874/1000 ----------------FAILED
# Episode 875/1000 --------------------FAILED
# Episode 876/1000 ---------------FAILED
# Episode 877/1000 -------FAILED
# Episode 878/1000 ----------------------------------------------------------------FAILED
# Episode 879/1000 ------------------------FAILED
# Episode 880/1000 --------------------------------------FAILED
# Episode 881/1000 ---------FAILED
# Episode 882/1000 ----------------------------------------------------------FAILED
# Episode 883/1000 ---------------------------FAILED
# Episode 884/1000 ---------------FAILED
# Episode 885/1000 -----------------------------------------------------------SUCCESS
# Episode 886/1000 ------------------------------FAILED
# Episode 887/1000 ----------------------FAILED
# Episode 888/1000 --------------------------------SUCCESS
# Episode 889/1000 --------------------------------FAILED
# Episode 890/1000 -----------------------------------------SUCCESS
# Episode 891/1000 ------FAILED
# Episode 892/1000 ----------------------FAILED
# Episode 893/1000 -------------FAILED
# Episode 894/1000 --------------------------------------------------FAILED
# Episode 895/1000 --------------------------------------------------SUCCESS
# Episode 896/1000 ----------------------------------------------------------------------------------FAILED
# Episode 897/1000 ---FAILED
# Episode 898/1000 ----------SUCCESS
# Episode 899/1000 --------FAILED
# Episode 900/1000 -----------------------------------FAILED
# Episode 901/1000 -----------------------------FAILED
# Episode 902/1000 --------------------------------------------------------------------------FAILED
# Episode 903/1000 -----------------------------------------------------------FAILED
# Episode 904/1000 --------------------------------------------------------------SUCCESS
# Episode 905/1000 ----------------------------------FAILED
# Episode 906/1000 ---------------------------------------------SUCCESS
# Episode 907/1000 ---------------SUCCESS
# Episode 908/1000 ----------------------------FAILED
# Episode 909/1000 -------------------------------------FAILED
# Episode 910/1000 --------SUCCESS
# Episode 911/1000 ----------------------------SUCCESS
# Episode 912/1000 --------------------------------FAILED
# Episode 913/1000 ---------------------SUCCESS
# Episode 914/1000 --FAILED
# Episode 915/1000 ------------------FAILED
# Episode 916/1000 --------------------------------------------------------------------------------------------SUCCESS
# Episode 917/1000 ----------------------------FAILED
# Episode 918/1000 -----------------------------------------------------------------------------------SUCCESS
# Episode 919/1000 -----------------------------SUCCESS
# Episode 920/1000 ---------SUCCESS
# Episode 921/1000 ----------------------------------------------------------------------------------------------------
# Episode 922/1000 --------------FAILED
# Episode 923/1000 ------------------------------------FAILED
# Episode 924/1000 -----------------------------------------FAILED
# Episode 925/1000 ------FAILED
# Episode 926/1000 ---------------FAILED
# Episode 927/1000 --------SUCCESS
# Episode 928/1000 ---------------FAILED
# Episode 929/1000 ----FAILED
# Episode 930/1000 -----------------------SUCCESS
# Episode 931/1000 -------------------------------------------------------------------------SUCCESS
# Episode 932/1000 ------------------------------FAILED
# Episode 933/1000 ----------------------------------------------------------------------------------------------------
# Episode 934/1000 ----FAILED
# Episode 935/1000 ------------------------------------FAILED
# Episode 936/1000 ---------------------------------SUCCESS
# Episode 937/1000 ----------------FAILED
# Episode 938/1000 --------------------------------------FAILED
# Episode 939/1000 ----------------------------------------------------------------------------------------------------
# Episode 940/1000 -----FAILED
# Episode 941/1000 ------FAILED
# Episode 942/1000 --------------------------------------------------------------------------------------------------SUCCESS
# Episode 943/1000 ------FAILED
# Episode 944/1000 ----------------------------------------------------------------------------------------------------
# Episode 945/1000 --FAILED
# Episode 946/1000 ----------------FAILED
# Episode 947/1000 ------------------FAILED
# Episode 948/1000 --------------------------------------------------------------------------FAILED
# Episode 949/1000 -----------------FAILED
# Episode 950/1000 ---------------------------------------------------SUCCESS
# Episode 951/1000 ------------------------SUCCESS
# Episode 952/1000 ----------------------------------------------------------------------------------------------------
# Episode 953/1000 ---------------------------------------SUCCESS
# Episode 954/1000 ---------------------------------------------------------------------------FAILED
# Episode 955/1000 -----------------------------------FAILED
# Episode 956/1000 ----------------------------SUCCESS
# Episode 957/1000 ----------------------------------------SUCCESS
# Episode 958/1000 -------------------------------------------------------------------------------------------------FAILED
# Episode 959/1000 -----------------------------FAILED
# Episode 960/1000 --------------------------SUCCESS
# Episode 961/1000 ----------------------------------------------------------------------------------------------------
# Episode 962/1000 --------------------------------------------------------------------SUCCESS
# Episode 963/1000 --------------------------FAILED
# Episode 964/1000 ---------------------SUCCESS
# Episode 965/1000 -------------------------------------------------------------------------------SUCCESS
# Episode 966/1000 ----------------------------------------------------------------------------------------------------
# Episode 967/1000 ----------------------------------------------------------------------------------------------------
# Episode 968/1000 ------------------------FAILED
# Episode 969/1000 -------------SUCCESS
# Episode 970/1000 ----------------------------------------------------------------------------------------------------
# Episode 971/1000 ----------------------------FAILED
# Episode 972/1000 -------------------------SUCCESS
# Episode 973/1000 -----------SUCCESS
# Episode 974/1000 -------------------------FAILED
# Episode 975/1000 ----------------------------------------------------------------------------------------------------
# Episode 976/1000 ----------------------------------------------------------------------------------------------------
# Episode 977/1000 -----------------SUCCESS
# Episode 978/1000 ---------------------SUCCESS
# Episode 979/1000 ----------------------------------------------------------------------------------------------------
# Episode 980/1000 ---------SUCCESS
# Episode 981/1000 -----------------------------------------------------------------------------------SUCCESS
# Episode 982/1000 ---------FAILED
# Episode 983/1000 ----------------------------------------------------------------------------------------------------
# Episode 984/1000 ----------------------------------------------------------------------------------------SUCCESS
# Episode 985/1000 --------------SUCCESS
# Episode 986/1000 -------------------------------------------------------------------------------------SUCCESS
# Episode 987/1000 ----------------------SUCCESS
# Episode 988/1000 --------------------------------------------------------------------------------------------------FAILED
# Episode 989/1000 ----------------------------------------------------------------------------------------------------
# Episode 990/1000 ----------------------------------------------------------------------------------------------------
# Episode 991/1000 ----------------------------------------------------------------------------FAILED
# Episode 992/1000 -----------------------------------------------------------------SUCCESS
# Episode 993/1000 -------SUCCESS
# Episode 994/1000 -----------------------------------SUCCESS
# Episode 995/1000 ----------------------------------------------------------------------------------FAILED
# Episode 996/1000 ----------FAILED
# Episode 997/1000 ----------------------------------------------------------------------------------------------------
# Episode 998/1000 ------SUCCESS
# Episode 999/1000 --------------------------------SUCCESS
# Episode 1000/1000 -------------------SUCCESS
# Completed 123/1000

# %% [markdown]
# ## Test Q-table (the `agent`)

# %%
q_table.q_table
# Out:
# array([[-2.06952362, -1.18700144, -1.9975492 , -2.01918666],
#        [-6.63367372, -6.10958537, -4.73099712, -1.18219919],
#        [-3.01577792, -2.80847895, -2.63912003, -2.09304602],
#        [-4.97200811, -4.82077609, -4.23417131, -2.41452257],
#        [-1.1113254 , -3.68132603, -3.6246798 , -4.40315683],
#        [ 0.        ,  0.        ,  0.        ,  0.        ],
#        [-7.62319521, -8.36069396, -4.00623342, -7.08713114],
#        [ 0.        ,  0.        ,  0.        ,  0.        ],
#        [-4.42125827, -2.55609826, -5.29127536, -0.61116544],
#        [-3.44395802,  1.06824206, -5.9806985 , -2.42490136],
#        [ 2.17252481, -1.96198101, -6.6115975 , -4.56528322],
#        [ 0.        ,  0.        ,  0.        ,  0.        ],
#        [ 0.        ,  0.        ,  0.        ,  0.        ],
#        [-5.7740482 , -2.60441218,  1.64062806, -3.06680809],
#        [ 1.6155042 ,  6.79209893,  3.07980494,  1.58253021],
#        [ 0.        ,  0.        ,  0.        ,  0.        ]])

# %%
state = env.reset()
env.render()
# Out:
# SFFF
# FHFH
# FFFH
# HFFG

# %% [markdown]
# Run this `cell` repeatedly to observe the `agent`

# %%
obs = env.step(q_table.get_next_action(state))
print(obs)

new_state, reward, done, info = obs
state = new_state
env.render()
# Out:
# (15, 0, True, {'prob': 1.0})
#   (Left)
# SFFF
# FHFH
# FFFH
# HFFG
